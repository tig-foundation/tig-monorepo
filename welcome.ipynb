# %%
# !list_challenges
# Out:
# id: c001    name: satisfiability       status: active @ round 1
# id: c002    name: vehicle_routing      status: active @ round 1
# id: c003    name: knapsack             status: active @ round 1

# %%
# !list_algorithms knapsack
# Out:
# id: c003_a001    name: relative_opt_fast    status: merged @ round 1

# %%
# !download_algorithm satisfiability sat_global_opt
# Out:
# ...
# Algorithm 'sat_global_opt' downloaded and extracted to 'tig-algorithms/lib/satisfiability'.

# %%
# !test_algorithm satisfiability sat_global_opt [1000,300]
# Out:
# #processing: 0, #finished: 100 - (#solutions: 100, #invalid: 0, #no_output: 0, #errors: 0), elapsed: 1.50s, solution_ratio: 1.0000, solution_rate: 66.6667, score: 66.6667

# %%
# !tig-runtime
# Out:
# Executes an algorithm on a single challenge instance
#
# Usage: tig-runtime [OPTIONS] <SETTINGS> <RAND_HASH> <NONCE> <BINARY>
#
# Arguments:
#   <SETTINGS>   Settings json string or path to json file
#   <RAND_HASH>  A string used in seed generation
#   <NONCE>      Nonce value
#   <BINARY>     Path to a shared object (*.so) file
#
# Options:
#       --hyperparameters [<HYPERPARAMETERS>]
#           Hyperparameters json string or path to json file
#       --ptx [<PTX>]
#           Path to a CUDA ptx file
#       --fuel [<FUEL>]
#           Optional maximum fuel parameter [default: 2000000000]
#       --output [<OUTPUT_FOLDER>]
#           If set, the output data will be saved to this folder (default current directory)
#       --gpu [<GPU>]
#           Which GPU device to use
#   -h, --help
#           Print help
